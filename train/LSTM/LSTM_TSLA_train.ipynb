# %%
import os
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from keras.models import Sequential
from keras.layers import Input, LSTM, Dense
from keras.callbacks import EarlyStopping
from keras.losses import MeanSquaredError

# %%
# Set Parameters
SEQ_LEN = 60
EPOCHS = 100
BATCH_SIZE = 32
VAL_RATIO = 0.2

os.makedirs("model", exist_ok=True)
os.makedirs("scaler", exist_ok=True)
os.makedirs("data", exist_ok=True)

ticker = "TSLA"
features = ["Close"]
CLOSE_IDX = features.index("Close")

# %%
# Define Sequence Creation Function
def create_sequences(data, seq_len=60):
    X, y = [], []
    for i in range(len(data) - seq_len):
        X.append(data[i:i+seq_len])
        y.append(data[i+seq_len, CLOSE_IDX])
    return np.array(X), np.array(y)

# %%
# Load preprocessed data
df = pd.read_csv(f"data/{ticker}_preprocess.csv")
df = df.sort_values("Date")

# Extract selected features
data = df[features].values

# Split into train+val and test sets
total_len = len(data)
test_start_idx = int(total_len * 0.8)
train_val_data = data[:test_start_idx]
test_data = data[test_start_idx - SEQ_LEN:]

# %%
# Split train_val into train and validation
train_size = int(len(train_val_data) * (1 - VAL_RATIO))
train_data = train_val_data[:train_size]
val_data = train_val_data[train_size - SEQ_LEN:]

# %%
# Scale the Data
scaler = MinMaxScaler()
scaler.fit(train_data)

train_scaled = scaler.transform(train_data)
val_scaled = scaler.transform(val_data)
test_scaled = scaler.transform(test_data)

# %%
# Create Sequences for LSTM
X_train, y_train = create_sequences(train_scaled, SEQ_LEN)
X_val, y_val = create_sequences(val_scaled, SEQ_LEN)
X_test, y_test = create_sequences(test_scaled, SEQ_LEN)

X_train = X_train.reshape((X_train.shape[0], SEQ_LEN, len(features)))
X_val = X_val.reshape((X_val.shape[0], SEQ_LEN, len(features)))
X_test = X_test.reshape((X_test.shape[0], SEQ_LEN, len(features)))

# %%
# Build the LSTM Model
model = Sequential([
    Input(shape=(SEQ_LEN, len(features))),
    LSTM(128, return_sequences=True),
    LSTM(64, return_sequences=False),
    Dense(1)
])
model.compile(optimizer="adam", loss=MeanSquaredError())
early_stop = EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)

# %%
# Train the Model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - loss: 0.0832 - val_loss: 0.0029
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 12/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 13/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 0.0015 - val_loss: 9.8395e-04
# Epoch 14/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 15/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 16/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0018 - val_loss: 8.6517e-04
# Epoch 17/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - loss: 0.0023 - val_loss: 9.5638e-04
# Epoch 18/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 19/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - loss: 0.0014 - val_loss: 9.9376e-04
# Epoch 20/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - loss: 0.0017 - val_loss: 8.3422e-04
# Epoch 21/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 183ms/step - loss: 0.0012 - val_loss: 7.2663e-04
# Epoch 22/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.0011 - val_loss: 8.5381e-04
# Epoch 23/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - loss: 9.6487e-04 - val_loss: 0.0024
# Epoch 24/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - loss: 0.0018 - val_loss: 7.2330e-04
# Epoch 25/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0012 - val_loss: 7.7253e-04
# Epoch 26/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - loss: 0.0011 - val_loss: 8.7513e-04
# Epoch 27/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - loss: 0.0013 - val_loss: 7.0013e-04
# Epoch 28/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 9.8353e-04 - val_loss: 0.0011
# Epoch 29/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0013 - val_loss: 9.3462e-04
# Epoch 30/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - loss: 0.0014 - val_loss: 7.9486e-04
# Epoch 31/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0011 - val_loss: 6.0930e-04
# Epoch 32/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - loss: 8.9544e-04 - val_loss: 5.7001e-04
# Epoch 33/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 9.2215e-04 - val_loss: 8.4779e-04
# Epoch 34/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - loss: 9.4128e-04 - val_loss: 6.2742e-04
# Epoch 35/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - loss: 8.7278e-04 - val_loss: 5.7590e-04
# Epoch 36/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 8.7040e-04 - val_loss: 6.8529e-04
# Epoch 37/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - loss: 8.9603e-04 - val_loss: 5.2172e-04
# Epoch 38/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - loss: 8.3299e-04 - val_loss: 7.3835e-04
# Epoch 39/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - loss: 0.0011 - val_loss: 5.1444e-04
# Epoch 40/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - loss: 8.3465e-04 - val_loss: 5.2565e-04
# Epoch 41/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - loss: 8.6902e-04 - val_loss: 5.4081e-04
# Epoch 42/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - loss: 7.6309e-04 - val_loss: 4.9173e-04
# Epoch 43/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - loss: 8.4177e-04 - val_loss: 7.7554e-04
# Epoch 44/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - loss: 0.0011 - val_loss: 4.8717e-04
# Epoch 45/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - loss: 7.8816e-04 - val_loss: 9.6611e-04
# Epoch 46/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - loss: 8.7456e-04 - val_loss: 4.8437e-04
# Epoch 47/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - loss: 8.9700e-04 - val_loss: 8.0280e-04
# Epoch 48/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - loss: 9.5686e-04 - val_loss: 5.2918e-04
# Epoch 49/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 7.7929e-04 - val_loss: 7.7459e-04
# Epoch 50/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 8.6119e-04 - val_loss: 6.4590e-04
# Epoch 51/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - loss: 7.2547e-04 - val_loss: 8.4079e-04
# Epoch 52/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - loss: 0.0010 - val_loss: 8.8221e-04
# Epoch 53/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 8.0917e-04 - val_loss: 5.5021e-04
# Epoch 54/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 7.1052e-04 - val_loss: 4.2297e-04
# Epoch 55/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 6.5320e-04 - val_loss: 5.3202e-04
# Epoch 56/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - loss: 7.4498e-04 - val_loss: 4.1693e-04
# Epoch 57/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - loss: 6.8776e-04 - val_loss: 5.0005e-04
# Epoch 58/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 9.0714e-04 - val_loss: 5.1152e-04
# Epoch 59/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 7.4804e-04 - val_loss: 4.0837e-04
# Epoch 60/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - loss: 6.8561e-04 - val_loss: 3.9524e-04
# Epoch 61/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - loss: 6.3373e-04 - val_loss: 4.5404e-04
# Epoch 62/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - loss: 6.0395e-04 - val_loss: 5.1118e-04
# Epoch 63/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 6.3951e-04 - val_loss: 4.2674e-04
# Epoch 64/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - loss: 6.6706e-04 - val_loss: 4.4464e-04
# Epoch 65/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - loss: 6.4750e-04 - val_loss: 3.7651e-04

# %%
# Make Predictions and Inverse Scale
y_pred_scaled = model.predict(X_test)

# Inverse transform only the 'Close' column
temp_array = np.zeros((len(y_pred_scaled), len(features)))
temp_array[:, CLOSE_IDX] = y_pred_scaled.flatten()
y_pred = scaler.inverse_transform(temp_array)[:, CLOSE_IDX]

temp_array_true = np.zeros((len(y_test), len(features)))
temp_array_true[:, CLOSE_IDX] = y_test
y_true = scaler.inverse_transform(temp_array_true)[:, CLOSE_IDX]
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step

# %%
# Evaluate the Model
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
r2 = r2_score(y_true, y_pred)

print(f"Model evaluation for {ticker} on the test set:")
print(f"  MAE:  {mae:.2f}")
print(f"  RMSE: {rmse:.2f}")
print(f"  MAPE: {mape:.2f}%")
print(f"  R^2:  {r2:.4f}")
# Out:
# Model evaluation for TSLA on the test set:
#   MAE:  9.64
#   RMSE: 13.43
#   MAPE: 3.57%
#   R^2:  0.9713

# %%
# Plot Predictions and Loss Curve
plt.figure(figsize=(10, 4))
plt.plot(y_true, label="Actual Price")
plt.plot(y_pred, label="Predicted Price")
plt.title(f"Price Prediction for {ticker} using LSTM")
plt.xlabel("Time Step")
plt.ylabel("Price")
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title(f"{ticker} - Loss Curve (LSTM)")
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Save the trained model and the fitted scaler for later use
model.save(f"model/LSTM_{ticker}_model.keras")
joblib.dump(scaler, f"scaler/LSTM_{ticker}_scaler.pkl")
# Out:
# ['scaler/LSTM_TSLA_scaler.pkl']
