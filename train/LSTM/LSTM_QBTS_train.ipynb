# %%
import os
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from keras.models import Sequential
from keras.layers import Input, LSTM, Dense
from keras.callbacks import EarlyStopping
from keras.losses import MeanSquaredError

# %%
# Set Parameters
SEQ_LEN = 40
EPOCHS = 100
BATCH_SIZE = 32
VAL_RATIO = 0.2

os.makedirs("model", exist_ok=True)
os.makedirs("scaler", exist_ok=True)
os.makedirs("data", exist_ok=True)

ticker = "QBTS"
features = ["Close"]
CLOSE_IDX = features.index("Close")

# %%
# Define Sequence Creation Function
def create_sequences(data, seq_len=60):
    X, y = [], []
    for i in range(len(data) - seq_len):
        X.append(data[i:i+seq_len])
        y.append(data[i+seq_len, CLOSE_IDX])
    return np.array(X), np.array(y)

# %%
# Load preprocessed data
df = pd.read_csv(f"data/{ticker}_preprocess.csv")
df = df.sort_values("Date")

# Extract selected features
data = df[features].values

# Split into train+val and test sets
total_len = len(data)
test_start_idx = int(total_len * 0.8)
train_val_data = data[:test_start_idx]
test_data = data[test_start_idx - SEQ_LEN:]

# %%
# Split train_val into train and validation
train_size = int(len(train_val_data) * (1 - VAL_RATIO))
train_data = train_val_data[:train_size]
val_data = train_val_data[train_size - SEQ_LEN:]

# %%
# Scale the Data
scaler = MinMaxScaler()
scaler.fit(train_data)

train_scaled = scaler.transform(train_data)
val_scaled = scaler.transform(val_data)
test_scaled = scaler.transform(test_data)

# %%
# Create Sequences for LSTM
X_train, y_train = create_sequences(train_scaled, SEQ_LEN)
X_val, y_val = create_sequences(val_scaled, SEQ_LEN)
X_test, y_test = create_sequences(test_scaled, SEQ_LEN)

X_train = X_train.reshape((X_train.shape[0], SEQ_LEN, len(features)))
X_val = X_val.reshape((X_val.shape[0], SEQ_LEN, len(features)))
X_test = X_test.reshape((X_test.shape[0], SEQ_LEN, len(features)))

# %%
# Build the LSTM Model
model = Sequential([
    Input(shape=(SEQ_LEN, len(features))),
    LSTM(64, return_sequences=True),
    LSTM(32, return_sequences=False),
    Dense(1)
])
model.compile(optimizer="adam", loss=MeanSquaredError())
early_stop = EarlyStopping(monitor="loss", patience=5, restore_best_weights=True)

# %%
# Train the Model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - loss: 0.1349 - val_loss: 0.0028
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0097 - val_loss: 8.4134e-04
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0032 - val_loss: 4.8981e-04
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0021 - val_loss: 6.6986e-04
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0024 - val_loss: 4.2345e-04
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0021 - val_loss: 3.9433e-04
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0019 - val_loss: 3.0964e-04
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0024 - val_loss: 3.9765e-04
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0019 - val_loss: 3.8915e-04
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0023 - val_loss: 3.3995e-04
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0023 - val_loss: 3.3066e-04
# Epoch 12/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0017 - val_loss: 3.2662e-04
# Epoch 13/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0015 - val_loss: 2.8704e-04
# Epoch 14/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0015 - val_loss: 2.9599e-04
# Epoch 15/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0017 - val_loss: 3.4165e-04
# Epoch 16/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0020 - val_loss: 2.6222e-04
# Epoch 17/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0016 - val_loss: 2.6384e-04
# Epoch 18/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0020 - val_loss: 2.4651e-04
# Epoch 19/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0016 - val_loss: 2.6930e-04
# Epoch 20/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 0.0015 - val_loss: 3.1493e-04
# Epoch 21/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0018 - val_loss: 2.5303e-04
# Epoch 22/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0013 - val_loss: 2.5847e-04
# Epoch 23/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0013 - val_loss: 2.3573e-04
# Epoch 24/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0022 - val_loss: 2.4256e-04
# Epoch 25/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0014 - val_loss: 2.3210e-04
# Epoch 26/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0015 - val_loss: 2.2571e-04
# Epoch 27/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0012 - val_loss: 2.3833e-04
# Epoch 28/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0013 - val_loss: 2.2170e-04
# Epoch 29/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0016 - val_loss: 2.4158e-04
# Epoch 30/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 0.0014 - val_loss: 2.2700e-04
# Epoch 31/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.0017 - val_loss: 2.1261e-04
# Epoch 32/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0012 - val_loss: 2.0984e-04
# Epoch 33/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0016 - val_loss: 2.2576e-04
# Epoch 34/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0014 - val_loss: 2.3563e-04
# Epoch 35/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0012 - val_loss: 2.0190e-04
# Epoch 36/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0010 - val_loss: 1.9926e-04
# Epoch 37/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0014 - val_loss: 1.9751e-04
# Epoch 38/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 9.9766e-04 - val_loss: 1.9739e-04
# Epoch 39/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0012 - val_loss: 1.9404e-04
# Epoch 40/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0016 - val_loss: 1.9356e-04
# Epoch 41/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 9.6198e-04 - val_loss: 2.1492e-04
# Epoch 42/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0010 - val_loss: 1.9492e-04
# Epoch 43/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 0.0010 - val_loss: 1.8867e-04
# Epoch 44/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 9.4614e-04 - val_loss: 1.8356e-04
# Epoch 45/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0015 - val_loss: 2.2190e-04
# Epoch 46/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 8.0095e-04 - val_loss: 1.8776e-04
# Epoch 47/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0011 - val_loss: 1.7846e-04
# Epoch 48/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0013 - val_loss: 2.3298e-04
# Epoch 49/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0010 - val_loss: 1.8520e-04
# Epoch 50/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 8.6674e-04 - val_loss: 1.7616e-04
# Epoch 51/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 7.3285e-04 - val_loss: 2.1127e-04
# Epoch 52/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 8.3439e-04 - val_loss: 1.7037e-04
# Epoch 53/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 9.4147e-04 - val_loss: 2.1737e-04
# Epoch 54/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 8.9263e-04 - val_loss: 1.7075e-04
# Epoch 55/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 9.1880e-04 - val_loss: 1.6538e-04
# Epoch 56/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0010 - val_loss: 2.0606e-04
# Epoch 57/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 8.3852e-04 - val_loss: 1.6708e-04
# Epoch 58/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 9.8334e-04 - val_loss: 1.7596e-04
# Epoch 59/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 8.3730e-04 - val_loss: 1.5941e-04
# Epoch 60/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 6.8708e-04 - val_loss: 1.6252e-04
# Epoch 61/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 8.2611e-04 - val_loss: 1.6410e-04
# Epoch 62/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 8.6861e-04 - val_loss: 1.5660e-04
# Epoch 63/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 0.0011 - val_loss: 1.5508e-04
# Epoch 64/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0011 - val_loss: 1.7036e-04
# Epoch 65/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 8.1907e-04 - val_loss: 1.5629e-04
# Epoch 66/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0011 - val_loss: 1.4813e-04
# Epoch 67/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 9.3954e-04 - val_loss: 1.7033e-04
# Epoch 68/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 9.0813e-04 - val_loss: 1.4827e-04
# Epoch 69/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 6.8867e-04 - val_loss: 1.6786e-04
# Epoch 70/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 8.1547e-04 - val_loss: 1.4356e-04
# Epoch 71/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0010 - val_loss: 1.6806e-04
# Epoch 72/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 6.2376e-04 - val_loss: 1.4487e-04
# Epoch 73/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 6.2501e-04 - val_loss: 1.5663e-04
# Epoch 74/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 8.9560e-04 - val_loss: 1.4317e-04
# Epoch 75/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 6.5324e-04 - val_loss: 1.3932e-04
# Epoch 76/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 8.6130e-04 - val_loss: 1.7091e-04
# Epoch 77/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 7.9081e-04 - val_loss: 1.4204e-04
# Epoch 78/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 7.0998e-04 - val_loss: 1.4624e-04
# Epoch 79/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 6.6600e-04 - val_loss: 1.6211e-04
# Epoch 80/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 8.1870e-04 - val_loss: 1.4540e-04
# Epoch 81/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 6.9841e-04 - val_loss: 1.3517e-04
# Epoch 82/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 6.3334e-04 - val_loss: 1.4484e-04
# Epoch 83/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 7.1301e-04 - val_loss: 1.3067e-04
# Epoch 84/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 6.5959e-04 - val_loss: 1.3098e-04
# Epoch 85/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 6.0809e-04 - val_loss: 1.3021e-04
# Epoch 86/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 5.6705e-04 - val_loss: 1.4343e-04
# Epoch 87/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 4.9335e-04 - val_loss: 1.2481e-04
# Epoch 88/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 5.2253e-04 - val_loss: 1.2644e-04
# Epoch 89/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.9230e-04 - val_loss: 1.2929e-04
# Epoch 90/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.6309e-04 - val_loss: 1.2610e-04
# Epoch 91/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 5.5991e-04 - val_loss: 1.3201e-04
# Epoch 92/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 6.0425e-04 - val_loss: 1.2379e-04

# %%
# Make Predictions and Inverse Scale
y_pred_scaled = model.predict(X_test)

# Inverse transform only the 'Close' column
temp_array = np.zeros((len(y_pred_scaled), len(features)))
temp_array[:, CLOSE_IDX] = y_pred_scaled.flatten()
y_pred = scaler.inverse_transform(temp_array)[:, CLOSE_IDX]

temp_array_true = np.zeros((len(y_test), len(features)))
temp_array_true[:, CLOSE_IDX] = y_test
y_true = scaler.inverse_transform(temp_array_true)[:, CLOSE_IDX]
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step

# %%
# Evaluate the Model
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
r2 = r2_score(y_true, y_pred)

print(f"Model evaluation for {ticker} on the test set:")
print(f"  MAE:  {mae:.2f}")
print(f"  RMSE: {rmse:.2f}")
print(f"  MAPE: {mape:.2f}%")
print(f"  R^2:  {r2:.4f}")
# Out:
# Model evaluation for QBTS on the test set:
#   MAE:  0.43
#   RMSE: 0.83
#   MAPE: 9.14%
#   R^2:  0.9301

# %%
# Plot Predictions and Loss Curve
plt.figure(figsize=(10, 4))
plt.plot(y_true, label="Actual Price")
plt.plot(y_pred, label="Predicted Price")
plt.title(f"Price Prediction for {ticker} using LSTM")
plt.xlabel("Time Step")
plt.ylabel("Price")
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title(f"{ticker} - Loss Curve (LSTM)")
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Save the trained model and the fitted scaler for later use
model.save(f"model/LSTM_{ticker}_model.keras")
joblib.dump(scaler, f"scaler/LSTM_{ticker}_scaler.pkl")
# Out:
# ['scaler/LSTM_QBTS_scaler.pkl']
