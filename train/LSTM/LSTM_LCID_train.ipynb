# %%
import os
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from keras.models import Sequential
from keras.layers import Input, LSTM, Dense
from keras.callbacks import EarlyStopping
from keras.losses import MeanSquaredError

# %%
# Set Parameters
SEQ_LEN = 60
EPOCHS = 100
BATCH_SIZE = 32
VAL_RATIO = 0.2

os.makedirs("model", exist_ok=True)
os.makedirs("scaler", exist_ok=True)
os.makedirs("data", exist_ok=True)

ticker = "LCID"
features = ["Close"]
CLOSE_IDX = features.index("Close")

# %%
# Define Sequence Creation Function
def create_sequences(data, seq_len=60):
    X, y = [], []
    for i in range(len(data) - seq_len):
        X.append(data[i:i+seq_len])
        y.append(data[i+seq_len, CLOSE_IDX])
    return np.array(X), np.array(y)

# %%
# Load preprocessed data
df = pd.read_csv(f"data/{ticker}_preprocess.csv")
df = df.sort_values("Date")

# Extract selected features
data = df[features].values

# Split into train+val and test sets
total_len = len(data)
test_start_idx = int(total_len * 0.8)
train_val_data = data[:test_start_idx]
test_data = data[test_start_idx - SEQ_LEN:]

# %%
# Split train_val into train and validation
train_size = int(len(train_val_data) * (1 - VAL_RATIO))
train_data = train_val_data[:train_size]
val_data = train_val_data[train_size - SEQ_LEN:]

# %%
# Scale the Data
scaler = MinMaxScaler()
scaler.fit(train_data)

train_scaled = scaler.transform(train_data)
val_scaled = scaler.transform(val_data)
test_scaled = scaler.transform(test_data)

# %%
# Create Sequences for LSTM
X_train, y_train = create_sequences(train_scaled, SEQ_LEN)
X_val, y_val = create_sequences(val_scaled, SEQ_LEN)
X_test, y_test = create_sequences(test_scaled, SEQ_LEN)

X_train = X_train.reshape((X_train.shape[0], SEQ_LEN, len(features)))
X_val = X_val.reshape((X_val.shape[0], SEQ_LEN, len(features)))
X_test = X_test.reshape((X_test.shape[0], SEQ_LEN, len(features)))

# %%
# Build the LSTM Model
model = Sequential([
    Input(shape=(SEQ_LEN, len(features))),
    LSTM(128, return_sequences=True),
    LSTM(64, return_sequences=False),
    Dense(1)
])
model.compile(optimizer="adam", loss=MeanSquaredError())
early_stop = EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)

# %%
# Train the Model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 188ms/step - loss: 0.0306 - val_loss: 7.0390e-04
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - loss: 0.0059 - val_loss: 4.7934e-05
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0039 - val_loss: 7.3823e-04
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0036 - val_loss: 5.2987e-05
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - loss: 0.0043 - val_loss: 7.0556e-05
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0030 - val_loss: 3.6013e-05
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0028 - val_loss: 9.4810e-05
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 0.0030 - val_loss: 3.7107e-05
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0028 - val_loss: 1.3220e-04
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.0019 - val_loss: 6.2204e-05
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0034 - val_loss: 5.0381e-05
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - loss: 0.0025 - val_loss: 2.4554e-04
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.0021 - val_loss: 5.5528e-05
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.0020 - val_loss: 1.8149e-04
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0020 - val_loss: 3.5141e-05
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 0.0018 - val_loss: 6.7357e-05
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.0025 - val_loss: 8.5436e-05
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - loss: 0.0017 - val_loss: 1.1003e-04
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0018 - val_loss: 3.6436e-05
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0018 - val_loss: 7.4471e-05
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 0.0014 - val_loss: 3.5167e-05
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0015 - val_loss: 3.7728e-05
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 0.0013 - val_loss: 7.9911e-05
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.0016 - val_loss: 2.0027e-04
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 0.0016 - val_loss: 5.9751e-05
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - loss: 0.0015 - val_loss: 3.4306e-05
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0016 - val_loss: 2.1412e-04
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - loss: 0.0014 - val_loss: 1.0674e-04
# Epoch 29/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.0012 - val_loss: 1.9837e-05
# Epoch 30/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0016 - val_loss: 2.5979e-05
# Epoch 31/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.0018 - val_loss: 1.1043e-04
# Epoch 32/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - loss: 0.0018 - val_loss: 4.5261e-05
# Epoch 33/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0011 - val_loss: 1.8767e-04
# Epoch 34/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0015 - val_loss: 2.3545e-04
# Epoch 35/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.0011 - val_loss: 2.9130e-05
# Epoch 36/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - loss: 0.0012 - val_loss: 8.7058e-05
# Epoch 37/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0019 - val_loss: 3.4902e-05
# Epoch 38/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.0011 - val_loss: 7.7411e-05
# Epoch 39/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0017 - val_loss: 2.5420e-05
# Epoch 40/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 0.0014 - val_loss: 2.9528e-05
# Epoch 41/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.0013 - val_loss: 2.1208e-05
# Epoch 42/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0011 - val_loss: 2.4813e-05
# Epoch 43/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0011 - val_loss: 2.1748e-05
# Epoch 44/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - loss: 0.0013 - val_loss: 1.3502e-04
# Epoch 45/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.0016 - val_loss: 3.5763e-05
# Epoch 46/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0010 - val_loss: 2.1128e-05
# Epoch 47/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0013 - val_loss: 1.6649e-05
# Epoch 48/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.0012 - val_loss: 1.7192e-04

# %%
# Make Predictions and Inverse Scale
y_pred_scaled = model.predict(X_test)

# Inverse transform only the 'Close' column
temp_array = np.zeros((len(y_pred_scaled), len(features)))
temp_array[:, CLOSE_IDX] = y_pred_scaled.flatten()
y_pred = scaler.inverse_transform(temp_array)[:, CLOSE_IDX]

temp_array_true = np.zeros((len(y_test), len(features)))
temp_array_true[:, CLOSE_IDX] = y_test
y_true = scaler.inverse_transform(temp_array_true)[:, CLOSE_IDX]
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step

# %%
# Evaluate the Model
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
r2 = r2_score(y_true, y_pred)

print(f"Model evaluation for {ticker} on the test set:")
print(f"  MAE:  {mae:.2f}")
print(f"  RMSE: {rmse:.2f}")
print(f"  MAPE: {mape:.2f}%")
print(f"  R^2:  {r2:.4f}")
# Out:
# Model evaluation for LCID on the test set:
#   MAE:  0.16
#   RMSE: 0.21
#   MAPE: 5.49%
#   R^2:  0.8483

# %%
# Plot Predictions and Loss Curve
plt.figure(figsize=(10, 4))
plt.plot(y_true, label="Actual Price")
plt.plot(y_pred, label="Predicted Price")
plt.title(f"Price Prediction for {ticker} using LSTM")
plt.xlabel("Time Step")
plt.ylabel("Price")
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title(f"{ticker} - Loss Curve (LSTM)")
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Save the trained model and the fitted scaler for later use
model.save(f"model/LSTM_{ticker}_model.keras")
joblib.dump(scaler, f"scaler/LSTM_{ticker}_scaler.pkl")
# Out:
# ['scaler/LSTM_LCID_scaler.pkl']
