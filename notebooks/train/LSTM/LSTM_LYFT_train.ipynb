# %%
import os
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from keras.models import Sequential
from keras.layers import Input, LSTM, Dense
from keras.callbacks import EarlyStopping
from keras.losses import MeanSquaredError

# %%
# Set Parameters
SEQ_LEN = 60
EPOCHS = 100
BATCH_SIZE = 32
VAL_RATIO = 0.2

os.makedirs("model", exist_ok=True)
os.makedirs("scaler", exist_ok=True)
os.makedirs("data", exist_ok=True)

ticker = "LYFT"
features = ["Close"]
CLOSE_IDX = features.index("Close")

# %%
# Define Sequence Creation Function
def create_sequences(data, seq_len=60):
    X, y = [], []
    for i in range(len(data) - seq_len):
        X.append(data[i:i+seq_len])
        y.append(data[i+seq_len, CLOSE_IDX])
    return np.array(X), np.array(y)

# %%
# Load preprocessed data
df = pd.read_csv(f"data/{ticker}_preprocess.csv")
df = df.sort_values("Date")

# Extract selected features
data = df[features].values

# Split into train+val and test sets
total_len = len(data)
test_start_idx = int(total_len * 0.8)
train_val_data = data[:test_start_idx]
test_data = data[test_start_idx - SEQ_LEN:]

# %%
# Split train_val into train and validation
train_size = int(len(train_val_data) * (1 - VAL_RATIO))
train_data = train_val_data[:train_size]
val_data = train_val_data[train_size - SEQ_LEN:]

# %%
# Scale the Data
scaler = MinMaxScaler()
scaler.fit(train_data)

train_scaled = scaler.transform(train_data)
val_scaled = scaler.transform(val_data)
test_scaled = scaler.transform(test_data)

# %%
# Create Sequences for LSTM
X_train, y_train = create_sequences(train_scaled, SEQ_LEN)
X_val, y_val = create_sequences(val_scaled, SEQ_LEN)
X_test, y_test = create_sequences(test_scaled, SEQ_LEN)

X_train = X_train.reshape((X_train.shape[0], SEQ_LEN, len(features)))
X_val = X_val.reshape((X_val.shape[0], SEQ_LEN, len(features)))
X_test = X_test.reshape((X_test.shape[0], SEQ_LEN, len(features)))

# %%
# Build the LSTM Model
model = Sequential([
    Input(shape=(SEQ_LEN, len(features))),
    LSTM(128, return_sequences=True),
    LSTM(64, return_sequences=False),
    Dense(1)
])
model.compile(optimizer="adam", loss=MeanSquaredError())
early_stop = EarlyStopping(monitor="loss", patience=5, restore_best_weights=True)

# %%
# Train the Model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 146ms/step - loss: 0.0809 - val_loss: 0.0028
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0054 - val_loss: 5.4964e-04
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - loss: 0.0029 - val_loss: 5.2086e-04
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0031 - val_loss: 3.7851e-04
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - loss: 0.0027 - val_loss: 4.5405e-04
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.0026 - val_loss: 3.7683e-04
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0023 - val_loss: 3.5749e-04
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0022 - val_loss: 3.5265e-04
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - loss: 0.0021 - val_loss: 3.0764e-04
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0020 - val_loss: 3.6757e-04
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0027 - val_loss: 3.0133e-04
# Epoch 12/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 155ms/step - loss: 0.0017 - val_loss: 2.7944e-04
# Epoch 13/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - loss: 0.0018 - val_loss: 3.0926e-04
# Epoch 14/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - loss: 0.0018 - val_loss: 2.8128e-04
# Epoch 15/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 0.0018 - val_loss: 3.0825e-04
# Epoch 16/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0015 - val_loss: 2.6837e-04
# Epoch 17/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - loss: 0.0016 - val_loss: 3.5470e-04
# Epoch 18/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.0019 - val_loss: 2.5701e-04
# Epoch 19/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0017 - val_loss: 2.8605e-04
# Epoch 20/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - loss: 0.0015 - val_loss: 2.5916e-04
# Epoch 21/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - loss: 0.0013 - val_loss: 3.8750e-04
# Epoch 22/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0016 - val_loss: 2.4673e-04
# Epoch 23/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 0.0014 - val_loss: 2.4999e-04
# Epoch 24/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - loss: 0.0015 - val_loss: 2.9638e-04
# Epoch 25/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - loss: 0.0014 - val_loss: 2.3579e-04
# Epoch 26/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0013 - val_loss: 2.3766e-04
# Epoch 27/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0015 - val_loss: 2.3819e-04
# Epoch 28/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - loss: 0.0012 - val_loss: 2.3283e-04
# Epoch 29/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.0016 - val_loss: 2.8499e-04
# Epoch 30/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0013 - val_loss: 2.2457e-04
# Epoch 31/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0012 - val_loss: 2.1975e-04
# Epoch 32/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0010 - val_loss: 2.1841e-04
# Epoch 33/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - loss: 0.0011 - val_loss: 2.3488e-04
# Epoch 34/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0011 - val_loss: 2.1167e-04
# Epoch 35/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 9.8244e-04 - val_loss: 2.2660e-04
# Epoch 36/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - loss: 9.6920e-04 - val_loss: 2.1264e-04
# Epoch 37/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 9.8526e-04 - val_loss: 2.6604e-04
# Epoch 38/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - loss: 0.0012 - val_loss: 2.4684e-04
# Epoch 39/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0010 - val_loss: 2.4597e-04
# Epoch 40/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 9.5811e-04 - val_loss: 1.9682e-04
# Epoch 41/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 0.0015 - val_loss: 1.9675e-04
# Epoch 42/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - loss: 9.6182e-04 - val_loss: 2.0737e-04
# Epoch 43/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 9.3609e-04 - val_loss: 2.0447e-04
# Epoch 44/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 8.6919e-04 - val_loss: 1.9527e-04
# Epoch 45/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - loss: 8.8945e-04 - val_loss: 3.7466e-04
# Epoch 46/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.0011 - val_loss: 1.8483e-04
# Epoch 47/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - loss: 7.4912e-04 - val_loss: 3.5295e-04
# Epoch 48/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 8.5406e-04 - val_loss: 1.9764e-04
# Epoch 49/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 160ms/step - loss: 8.6231e-04 - val_loss: 2.1639e-04
# Epoch 50/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0011 - val_loss: 1.8429e-04
# Epoch 51/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 9.6614e-04 - val_loss: 2.2918e-04
# Epoch 52/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 133ms/step - loss: 7.4056e-04 - val_loss: 1.7186e-04
# Epoch 53/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - loss: 7.1019e-04 - val_loss: 2.1157e-04
# Epoch 54/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 7.7202e-04 - val_loss: 1.9775e-04
# Epoch 55/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step - loss: 7.2891e-04 - val_loss: 1.8198e-04
# Epoch 56/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - loss: 9.8973e-04 - val_loss: 1.7126e-04
# Epoch 57/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - loss: 8.6819e-04 - val_loss: 1.7739e-04
# Epoch 58/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - loss: 6.8350e-04 - val_loss: 1.6313e-04
# Epoch 59/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 8.3265e-04 - val_loss: 1.9153e-04
# Epoch 60/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - loss: 7.3346e-04 - val_loss: 2.1502e-04
# Epoch 61/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - loss: 8.5719e-04 - val_loss: 1.8243e-04
# Epoch 62/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 7.6721e-04 - val_loss: 1.6352e-04
# Epoch 63/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 7.4696e-04 - val_loss: 1.7566e-04

# %%
# Make Predictions and Inverse Scale
y_pred_scaled = model.predict(X_test)

# Inverse transform only the 'Close' column
temp_array = np.zeros((len(y_pred_scaled), len(features)))
temp_array[:, CLOSE_IDX] = y_pred_scaled.flatten()
y_pred = scaler.inverse_transform(temp_array)[:, CLOSE_IDX]

temp_array_true = np.zeros((len(y_test), len(features)))
temp_array_true[:, CLOSE_IDX] = y_test
y_true = scaler.inverse_transform(temp_array_true)[:, CLOSE_IDX]
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step

# %%
# Evaluate the Model
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
r2 = r2_score(y_true, y_pred)

print(f"Model evaluation for {ticker} on the test set:")
print(f"  MAE:  {mae:.2f}")
print(f"  RMSE: {rmse:.2f}")
print(f"  MAPE: {mape:.2f}%")
print(f"  R^2:  {r2:.4f}")
# Out:
# Model evaluation for LYFT on the test set:
#   MAE:  0.45
#   RMSE: 0.67
#   MAPE: 3.29%
#   R^2:  0.8918

# %%
# Plot Predictions and Loss Curve
plt.figure(figsize=(10, 4))
plt.plot(y_true, label="Actual Price")
plt.plot(y_pred, label="Predicted Price")
plt.title(f"Price Prediction for {ticker} using LSTM")
plt.xlabel("Time Step")
plt.ylabel("Price")
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title(f"{ticker} - Loss Curve (LSTM)")
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Save the trained model and the fitted scaler for later use
model.save(f"model/LSTM_{ticker}_model.keras")
joblib.dump(scaler, f"scaler/LSTM_{ticker}_scaler.pkl")
# Out:
# ['scaler/LSTM_LYFT_scaler.pkl']
