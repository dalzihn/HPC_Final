# %%
import os
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from keras.models import Sequential
from keras.layers import Input, GRU, Dense
from keras.callbacks import EarlyStopping
from keras.losses import MeanSquaredError

# %%
# Set Parameters
SEQ_LEN = 60
EPOCHS = 100
BATCH_SIZE = 32
VAL_RATIO = 0.2

os.makedirs("model", exist_ok=True)
os.makedirs("scaler", exist_ok=True)
os.makedirs("data", exist_ok=True)

ticker = "QBTS"
features = ["Close"]
CLOSE_IDX = features.index("Close")

# %%
# Define Sequence Creation Function
def create_sequences(data, seq_len=60):
    X, y = [], []
    for i in range(len(data) - seq_len):
        X.append(data[i:i+seq_len])
        y.append(data[i+seq_len, CLOSE_IDX])
    return np.array(X), np.array(y)

# %%
# Load preprocessed data
df = pd.read_csv(f"data/{ticker}_preprocess.csv")
df = df.sort_values("Date")

# Extract selected features
data = df[features].values

# Split into train+val and test sets
total_len = len(data)
test_start_idx = int(total_len * 0.8)
train_val_data = data[:test_start_idx]
test_data = data[test_start_idx - SEQ_LEN:]

# %%
# Split train_val into train and validation
train_size = int(len(train_val_data) * (1 - VAL_RATIO))
train_data = train_val_data[:train_size]
val_data = train_val_data[train_size - SEQ_LEN:]

# %%
# Scale the Data
scaler = MinMaxScaler()
scaler.fit(train_data)

train_scaled = scaler.transform(train_data)
val_scaled = scaler.transform(val_data)
test_scaled = scaler.transform(test_data)

# %%
# Create Sequences for GRU
X_train, y_train = create_sequences(train_scaled, SEQ_LEN)
X_val, y_val = create_sequences(val_scaled, SEQ_LEN)
X_test, y_test = create_sequences(test_scaled, SEQ_LEN)

X_train = X_train.reshape((X_train.shape[0], SEQ_LEN, len(features)))
X_val = X_val.reshape((X_val.shape[0], SEQ_LEN, len(features)))
X_test = X_test.reshape((X_test.shape[0], SEQ_LEN, len(features)))

# %%
# Build the GRU Model
model = Sequential([
    Input(shape=(SEQ_LEN, len(features))),
    GRU(128, return_sequences=True),
    GRU(64, return_sequences=False),
    Dense(1)
])

model.compile(optimizer="adam", loss=MeanSquaredError())
early_stop = EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)

# %%
# Train the Model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - loss: 0.1294 - val_loss: 8.3212e-04
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0040 - val_loss: 5.6252e-04
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - loss: 0.0016 - val_loss: 4.6988e-04
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0011 - val_loss: 1.5971e-04
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0011 - val_loss: 1.4287e-04
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0011 - val_loss: 1.5395e-04
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - loss: 9.3332e-04 - val_loss: 1.5964e-04
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0011 - val_loss: 1.6626e-04
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 8.3663e-04 - val_loss: 1.3833e-04
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 8.2652e-04 - val_loss: 1.3642e-04
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - loss: 8.5070e-04 - val_loss: 1.4601e-04
# Epoch 12/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 8.7866e-04 - val_loss: 1.2059e-04
# Epoch 13/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 9.4512e-04 - val_loss: 1.2352e-04
# Epoch 14/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 7.0522e-04 - val_loss: 1.4913e-04
# Epoch 15/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 6.8348e-04 - val_loss: 1.4281e-04
# Epoch 16/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - loss: 7.0367e-04 - val_loss: 1.1055e-04
# Epoch 17/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 4.6226e-04 - val_loss: 1.1739e-04
# Epoch 18/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 4.6958e-04 - val_loss: 1.0798e-04
# Epoch 19/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - loss: 7.0097e-04 - val_loss: 1.1719e-04
# Epoch 20/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 6.0168e-04 - val_loss: 1.0907e-04
# Epoch 21/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 5.1186e-04 - val_loss: 1.0322e-04
# Epoch 22/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 4.4027e-04 - val_loss: 1.0641e-04
# Epoch 23/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 5.3831e-04 - val_loss: 1.0149e-04
# Epoch 24/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 6.5790e-04 - val_loss: 1.1469e-04
# Epoch 25/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 4.5543e-04 - val_loss: 1.0350e-04
# Epoch 26/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 4.1640e-04 - val_loss: 1.0172e-04
# Epoch 27/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 4.8900e-04 - val_loss: 9.4186e-05
# Epoch 28/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - loss: 4.8782e-04 - val_loss: 9.5561e-05
# Epoch 29/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - loss: 6.6036e-04 - val_loss: 9.4950e-05
# Epoch 30/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 5.4118e-04 - val_loss: 1.1974e-04
# Epoch 31/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 4.7805e-04 - val_loss: 1.0231e-04
# Epoch 32/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 3.2074e-04 - val_loss: 8.7954e-05
# Epoch 33/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 6.1987e-04 - val_loss: 1.5052e-04
# Epoch 34/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - loss: 4.2050e-04 - val_loss: 8.6386e-05
# Epoch 35/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 4.4354e-04 - val_loss: 9.4880e-05
# Epoch 36/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 6.4168e-04 - val_loss: 9.8867e-05
# Epoch 37/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 4.2101e-04 - val_loss: 1.1737e-04
# Epoch 38/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - loss: 5.4854e-04 - val_loss: 1.0631e-04
# Epoch 39/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 3.5994e-04 - val_loss: 8.6287e-05
# Epoch 40/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 5.6882e-04 - val_loss: 8.6686e-05
# Epoch 41/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 3.7246e-04 - val_loss: 8.1553e-05
# Epoch 42/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 4.4570e-04 - val_loss: 8.4864e-05
# Epoch 43/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 3.8264e-04 - val_loss: 8.9536e-05
# Epoch 44/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 2.9733e-04 - val_loss: 8.1864e-05
# Epoch 45/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 4.4870e-04 - val_loss: 9.6840e-05
# Epoch 46/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 3.8273e-04 - val_loss: 9.4865e-05
# Epoch 47/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 3.4956e-04 - val_loss: 1.0269e-04
# Epoch 48/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 2.9983e-04 - val_loss: 8.1463e-05
# Epoch 49/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 3.9892e-04 - val_loss: 1.0289e-04
# Epoch 50/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 6.0978e-04 - val_loss: 7.9741e-05
# Epoch 51/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 2.6847e-04 - val_loss: 1.0890e-04
# Epoch 52/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 4.7345e-04 - val_loss: 7.4737e-05
# Epoch 53/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 4.0159e-04 - val_loss: 7.6308e-05
# Epoch 54/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 4.9052e-04 - val_loss: 7.3459e-05
# Epoch 55/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 4.0678e-04 - val_loss: 7.2816e-05
# Epoch 56/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - loss: 3.7925e-04 - val_loss: 7.4805e-05
# Epoch 57/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - loss: 4.8812e-04 - val_loss: 7.5092e-05
# Epoch 58/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 3.6868e-04 - val_loss: 8.6598e-05
# Epoch 59/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 4.3165e-04 - val_loss: 1.3407e-04
# Epoch 60/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 4.2157e-04 - val_loss: 7.3227e-05
# Epoch 61/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - loss: 4.5331e-04 - val_loss: 7.5609e-05
# Epoch 62/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 4.3707e-04 - val_loss: 7.0580e-05
# Epoch 63/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 3.2570e-04 - val_loss: 7.3818e-05
# Epoch 64/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 4.1031e-04 - val_loss: 8.0800e-05
# Epoch 65/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 3.3848e-04 - val_loss: 7.2957e-05
# Epoch 66/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 3.9906e-04 - val_loss: 7.1552e-05
# Epoch 67/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 3.1840e-04 - val_loss: 1.1552e-04
# Epoch 68/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 3.9842e-04 - val_loss: 7.6511e-05
# Epoch 69/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 3.9714e-04 - val_loss: 8.4340e-05
# Epoch 70/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - loss: 3.9222e-04 - val_loss: 7.5814e-05
# Epoch 71/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - loss: 4.1720e-04 - val_loss: 7.4103e-05
# Epoch 72/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 3.0478e-04 - val_loss: 7.4210e-05

# %%
# Make Predictions and Inverse Scale
y_pred_scaled = model.predict(X_test)

# Inverse transform only the 'Close' column
temp_array = np.zeros((len(y_pred_scaled), len(features)))
temp_array[:, CLOSE_IDX] = y_pred_scaled.flatten()
y_pred = scaler.inverse_transform(temp_array)[:, CLOSE_IDX]

temp_array_true = np.zeros((len(y_test), len(features)))
temp_array_true[:, CLOSE_IDX] = y_test
y_true = scaler.inverse_transform(temp_array_true)[:, CLOSE_IDX]
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step

# %%
# Evaluate the Model
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
r2 = r2_score(y_true, y_pred)

print(f"Model evaluation for {ticker} on the test set:")
print(f"  MAE:  {mae:.2f}")
print(f"  RMSE: {rmse:.2f}")
print(f"  MAPE: {mape:.2f}%")
print(f"  R^2:  {r2:.4f}")
# Out:
# Model evaluation for QBTS on the test set:
#   MAE:  0.33
#   RMSE: 0.65
#   MAPE: 7.09%
#   R^2:  0.9573

# %%
# Plot Predictions and Loss Curve
plt.figure(figsize=(10, 4))
plt.plot(y_true, label="Actual Price")
plt.plot(y_pred, label="Predicted Price")
plt.title(f"Price Prediction for {ticker} using GRU")
plt.xlabel("Time Step")
plt.ylabel("Price")
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title(f"{ticker} - Loss Curve (GRU)")
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Save the trained model and the fitted scaler for later use
model.save(f"model/GRU_{ticker}_model.keras")
joblib.dump(scaler, f"scaler/GRU_{ticker}_scaler.pkl")
# Out:
# ['scaler/GRU_QBTS_scaler.pkl']
