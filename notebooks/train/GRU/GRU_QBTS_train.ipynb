# %%
import os
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from keras.models import Sequential
from keras.layers import Input, GRU, Dense
from keras.callbacks import EarlyStopping
from keras.losses import MeanSquaredError

# %%
# Set Parameters
SEQ_LEN = 40
EPOCHS = 100
BATCH_SIZE = 32
VAL_RATIO = 0.2

os.makedirs("model", exist_ok=True)
os.makedirs("scaler", exist_ok=True)
os.makedirs("data", exist_ok=True)

ticker = "QBTS"
features = ["Close"]
CLOSE_IDX = features.index("Close")

# %%
# Define Sequence Creation Function
def create_sequences(data, seq_len=60):
    X, y = [], []
    for i in range(len(data) - seq_len):
        X.append(data[i:i+seq_len])
        y.append(data[i+seq_len, CLOSE_IDX])
    return np.array(X), np.array(y)

# %%
# Load preprocessed data
df = pd.read_csv(f"data/{ticker}_preprocess.csv")
df = df.sort_values("Date")

# Extract selected features
data = df[features].values

# Split into train+val and test sets
total_len = len(data)
test_start_idx = int(total_len * 0.8)
train_val_data = data[:test_start_idx]
test_data = data[test_start_idx - SEQ_LEN:]

# %%
# Split train_val into train and validation
train_size = int(len(train_val_data) * (1 - VAL_RATIO))
train_data = train_val_data[:train_size]
val_data = train_val_data[train_size - SEQ_LEN:]

# %%
# Scale the Data
scaler = MinMaxScaler()
scaler.fit(train_data)

train_scaled = scaler.transform(train_data)
val_scaled = scaler.transform(val_data)
test_scaled = scaler.transform(test_data)

# %%
# Create Sequences for GRU
X_train, y_train = create_sequences(train_scaled, SEQ_LEN)
X_val, y_val = create_sequences(val_scaled, SEQ_LEN)
X_test, y_test = create_sequences(test_scaled, SEQ_LEN)

X_train = X_train.reshape((X_train.shape[0], SEQ_LEN, len(features)))
X_val = X_val.reshape((X_val.shape[0], SEQ_LEN, len(features)))
X_test = X_test.reshape((X_test.shape[0], SEQ_LEN, len(features)))

# %%
# Build the GRU Model
model = Sequential([
    Input(shape=(SEQ_LEN, len(features))),
    GRU(64, return_sequences=True),
    GRU(32, return_sequences=False),
    Dense(1)
])

model.compile(optimizer="adam", loss=MeanSquaredError())
early_stop = EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)

# %%
# Train the Model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.1398 - val_loss: 0.0077
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0078 - val_loss: 0.0028
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0021 - val_loss: 1.7800e-04
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011 - val_loss: 2.3626e-04
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.2134e-04 - val_loss: 1.8169e-04
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.5385e-04 - val_loss: 1.6599e-04
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.9182e-04 - val_loss: 1.8204e-04
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.0669e-04 - val_loss: 1.6246e-04
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.2165e-04 - val_loss: 1.8425e-04
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.0001e-04 - val_loss: 1.9106e-04
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - val_loss: 1.6207e-04
# Epoch 12/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.3036e-04 - val_loss: 1.5256e-04
# Epoch 13/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.3588e-04 - val_loss: 1.5671e-04
# Epoch 14/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0011 - val_loss: 1.4435e-04
# Epoch 15/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.5691e-04 - val_loss: 1.5246e-04
# Epoch 16/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.1832e-04 - val_loss: 1.3994e-04
# Epoch 17/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.6735e-04 - val_loss: 1.6601e-04
# Epoch 18/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 7.0168e-04 - val_loss: 1.2935e-04
# Epoch 19/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.2447e-04 - val_loss: 1.2935e-04
# Epoch 20/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.3174e-04 - val_loss: 1.4733e-04
# Epoch 21/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.1477e-04 - val_loss: 1.2879e-04
# Epoch 22/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.8725e-04 - val_loss: 1.3253e-04
# Epoch 23/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.8952e-04 - val_loss: 1.1906e-04
# Epoch 24/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.7812e-04 - val_loss: 1.2639e-04
# Epoch 25/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.4791e-04 - val_loss: 1.1419e-04
# Epoch 26/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.0377e-04 - val_loss: 1.2022e-04
# Epoch 27/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.5676e-04 - val_loss: 1.3599e-04
# Epoch 28/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.3706e-04 - val_loss: 1.1562e-04
# Epoch 29/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.7387e-04 - val_loss: 1.1377e-04
# Epoch 30/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.5204e-04 - val_loss: 1.0942e-04
# Epoch 31/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.8226e-04 - val_loss: 1.2554e-04
# Epoch 32/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.9528e-04 - val_loss: 1.1382e-04
# Epoch 33/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.0116e-04 - val_loss: 1.0893e-04
# Epoch 34/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.7528e-04 - val_loss: 1.0127e-04
# Epoch 35/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.9896e-04 - val_loss: 1.0069e-04
# Epoch 36/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.3772e-04 - val_loss: 1.0091e-04
# Epoch 37/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.8554e-04 - val_loss: 9.8006e-05
# Epoch 38/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.0253e-04 - val_loss: 1.0136e-04
# Epoch 39/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6533e-04 - val_loss: 1.1896e-04
# Epoch 40/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.4762e-04 - val_loss: 9.7167e-05
# Epoch 41/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0329e-04 - val_loss: 9.3829e-05
# Epoch 42/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.1730e-04 - val_loss: 1.1691e-04
# Epoch 43/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9973e-04 - val_loss: 9.1499e-05
# Epoch 44/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.7372e-04 - val_loss: 9.7546e-05
# Epoch 45/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.1105e-04 - val_loss: 1.1266e-04
# Epoch 46/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.5810e-04 - val_loss: 9.6299e-05
# Epoch 47/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.0683e-04 - val_loss: 9.4548e-05
# Epoch 48/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.8328e-04 - val_loss: 8.8259e-05
# Epoch 49/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.0002e-04 - val_loss: 9.8204e-05
# Epoch 50/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.1752e-04 - val_loss: 1.1206e-04
# Epoch 51/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.9505e-04 - val_loss: 9.2867e-05
# Epoch 52/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.7959e-04 - val_loss: 8.5257e-05
# Epoch 53/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.9118e-04 - val_loss: 8.9238e-05
# Epoch 54/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0983e-04 - val_loss: 1.1421e-04
# Epoch 55/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.1734e-04 - val_loss: 8.4204e-05
# Epoch 56/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.8429e-04 - val_loss: 8.4147e-05
# Epoch 57/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0510e-04 - val_loss: 8.1604e-05
# Epoch 58/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.9987e-04 - val_loss: 8.3391e-05
# Epoch 59/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.3140e-04 - val_loss: 8.1104e-05
# Epoch 60/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.2592e-04 - val_loss: 8.8950e-05
# Epoch 61/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.7542e-04 - val_loss: 8.1269e-05
# Epoch 62/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.0092e-04 - val_loss: 8.0565e-05
# Epoch 63/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.9136e-04 - val_loss: 7.8778e-05
# Epoch 64/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.5413e-04 - val_loss: 8.9197e-05
# Epoch 65/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.1153e-04 - val_loss: 7.8203e-05
# Epoch 66/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.4489e-04 - val_loss: 8.0039e-05
# Epoch 67/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.9690e-04 - val_loss: 7.7984e-05
# Epoch 68/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7553e-04 - val_loss: 7.6596e-05
# Epoch 69/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6178e-04 - val_loss: 8.4961e-05
# Epoch 70/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.6164e-04 - val_loss: 8.3396e-05
# Epoch 71/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.7740e-04 - val_loss: 1.1234e-04
# Epoch 72/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.9066e-04 - val_loss: 7.5649e-05
# Epoch 73/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.0820e-04 - val_loss: 7.4706e-05
# Epoch 74/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0436e-04 - val_loss: 7.8361e-05
# Epoch 75/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.6630e-04 - val_loss: 7.4311e-05
# Epoch 76/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.9823e-04 - val_loss: 8.0123e-05
# Epoch 77/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.5199e-04 - val_loss: 7.6333e-05
# Epoch 78/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.6945e-04 - val_loss: 1.2898e-04
# Epoch 79/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.5988e-04 - val_loss: 8.1162e-05
# Epoch 80/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.9860e-04 - val_loss: 7.2728e-05
# Epoch 81/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.2809e-04 - val_loss: 7.5725e-05
# Epoch 82/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.6946e-04 - val_loss: 7.2473e-05
# Epoch 83/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.2118e-04 - val_loss: 7.1373e-05
# Epoch 84/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.7990e-04 - val_loss: 1.0025e-04
# Epoch 85/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.9840e-04 - val_loss: 7.5844e-05
# Epoch 86/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.7339e-04 - val_loss: 7.1146e-05
# Epoch 87/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.7067e-04 - val_loss: 1.2576e-04
# Epoch 88/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.1636e-04 - val_loss: 7.2480e-05
# Epoch 89/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.3584e-04 - val_loss: 9.2590e-05
# Epoch 90/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.0101e-04 - val_loss: 7.0279e-05
# Epoch 91/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.5176e-04 - val_loss: 9.9282e-05
# Epoch 92/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.1897e-04 - val_loss: 7.9212e-05
# Epoch 93/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.2587e-04 - val_loss: 7.9432e-05
# Epoch 94/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.9289e-04 - val_loss: 7.0763e-05
# Epoch 95/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9766e-04 - val_loss: 7.2369e-05
# Epoch 96/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.4687e-04 - val_loss: 6.9244e-05
# Epoch 97/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.6912e-04 - val_loss: 9.2217e-05
# Epoch 98/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.4107e-04 - val_loss: 9.3657e-05
# Epoch 99/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.3563e-04 - val_loss: 6.9041e-05
# Epoch 100/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5161e-04 - val_loss: 6.9585e-05

# %%
# Make Predictions and Inverse Scale
y_pred_scaled = model.predict(X_test)

# Inverse transform only the 'Close' column
temp_array = np.zeros((len(y_pred_scaled), len(features)))
temp_array[:, CLOSE_IDX] = y_pred_scaled.flatten()
y_pred = scaler.inverse_transform(temp_array)[:, CLOSE_IDX]

temp_array_true = np.zeros((len(y_test), len(features)))
temp_array_true[:, CLOSE_IDX] = y_test
y_true = scaler.inverse_transform(temp_array_true)[:, CLOSE_IDX]
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
# Evaluate the Model
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
r2 = r2_score(y_true, y_pred)

print(f"Model evaluation for {ticker} on the test set:")
print(f"  MAE:  {mae:.2f}")
print(f"  RMSE: {rmse:.2f}")
print(f"  MAPE: {mape:.2f}%")
print(f"  R^2:  {r2:.4f}")
# Out:
# Model evaluation for QBTS on the test set:
#   MAE:  0.32
#   RMSE: 0.64
#   MAPE: 7.03%
#   R^2:  0.9586

# %%
# Plot Predictions and Loss Curve
plt.figure(figsize=(10, 4))
plt.plot(y_true, label="Actual Price")
plt.plot(y_pred, label="Predicted Price")
plt.title(f"Price Prediction for {ticker} using GRU")
plt.xlabel("Time Step")
plt.ylabel("Price")
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title(f"{ticker} - Loss Curve (GRU)")
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Save the trained model and the fitted scaler for later use
model.save(f"model/GRU_{ticker}_model.keras")
joblib.dump(scaler, f"scaler/GRU_{ticker}_scaler.pkl")
# Out:
# ['scaler/GRU_QBTS_scaler.pkl']
