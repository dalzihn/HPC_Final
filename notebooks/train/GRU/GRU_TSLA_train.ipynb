# %%
import os
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from keras.models import Sequential
from keras.layers import Input, GRU, Dense
from keras.callbacks import EarlyStopping
from keras.losses import MeanSquaredError

# %%
# Set Parameters
SEQ_LEN = 60
EPOCHS = 100
BATCH_SIZE = 32
VAL_RATIO = 0.2

os.makedirs("model", exist_ok=True)
os.makedirs("scaler", exist_ok=True)
os.makedirs("data", exist_ok=True)

ticker = "TSLA"
features = ["Close"]
CLOSE_IDX = features.index("Close")

# %%
# Define Sequence Creation Function
def create_sequences(data, seq_len=60):
    X, y = [], []
    for i in range(len(data) - seq_len):
        X.append(data[i:i+seq_len])
        y.append(data[i+seq_len, CLOSE_IDX])
    return np.array(X), np.array(y)

# %%
# Load preprocessed data
df = pd.read_csv(f"data/{ticker}_preprocess.csv")
df = df.sort_values("Date")

# Extract selected features
data = df[features].values

# Split into train+val and test sets
total_len = len(data)
test_start_idx = int(total_len * 0.8)
train_val_data = data[:test_start_idx]
test_data = data[test_start_idx - SEQ_LEN:]

# %%
# Split train_val into train and validation
train_size = int(len(train_val_data) * (1 - VAL_RATIO))
train_data = train_val_data[:train_size]
val_data = train_val_data[train_size - SEQ_LEN:]

# %%
# Scale the Data
scaler = MinMaxScaler()
scaler.fit(train_data)

train_scaled = scaler.transform(train_data)
val_scaled = scaler.transform(val_data)
test_scaled = scaler.transform(test_data)

# %%
# Create Sequences for GRU
X_train, y_train = create_sequences(train_scaled, SEQ_LEN)
X_val, y_val = create_sequences(val_scaled, SEQ_LEN)
X_test, y_test = create_sequences(test_scaled, SEQ_LEN)

X_train = X_train.reshape((X_train.shape[0], SEQ_LEN, len(features)))
X_val = X_val.reshape((X_val.shape[0], SEQ_LEN, len(features)))
X_test = X_test.reshape((X_test.shape[0], SEQ_LEN, len(features)))

# %%
# Build the GRU Model
model = Sequential([
    Input(shape=(SEQ_LEN, len(features))),
    GRU(128, return_sequences=True),
    GRU(64, return_sequences=False),
    Dense(1)
])

model.compile(optimizer="adam", loss=MeanSquaredError())
early_stop = EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)

# %%
# Train the Model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 159ms/step - loss: 0.1029 - val_loss: 0.0013
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0041 - val_loss: 0.0012
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 0.0014 - val_loss: 7.0732e-04
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 155ms/step - loss: 0.0013 - val_loss: 6.6768e-04
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0011 - val_loss: 6.7547e-04
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 9.4283e-04 - val_loss: 6.6899e-04
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - loss: 9.8323e-04 - val_loss: 5.9363e-04
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - loss: 9.2843e-04 - val_loss: 5.4928e-04
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 8.6386e-04 - val_loss: 5.4084e-04
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 7.7189e-04 - val_loss: 6.0486e-04
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - loss: 8.0050e-04 - val_loss: 7.0068e-04
# Epoch 12/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 7.3740e-04 - val_loss: 5.1874e-04
# Epoch 13/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 7.1638e-04 - val_loss: 5.1280e-04
# Epoch 14/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 7.3920e-04 - val_loss: 5.0304e-04
# Epoch 15/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 6.8028e-04 - val_loss: 4.5010e-04
# Epoch 16/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - loss: 6.3330e-04 - val_loss: 4.3846e-04
# Epoch 17/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - loss: 6.3689e-04 - val_loss: 5.8117e-04
# Epoch 18/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - loss: 8.3368e-04 - val_loss: 4.1918e-04
# Epoch 19/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - loss: 5.7591e-04 - val_loss: 4.1251e-04
# Epoch 20/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 6.0788e-04 - val_loss: 4.5657e-04
# Epoch 21/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - loss: 7.4382e-04 - val_loss: 4.0584e-04
# Epoch 22/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - loss: 6.6933e-04 - val_loss: 4.0501e-04
# Epoch 23/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - loss: 6.5513e-04 - val_loss: 4.0289e-04
# Epoch 24/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 5.8213e-04 - val_loss: 3.8852e-04
# Epoch 25/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - loss: 6.1951e-04 - val_loss: 6.7102e-04
# Epoch 26/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 8.0304e-04 - val_loss: 4.6559e-04
# Epoch 27/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - loss: 6.1029e-04 - val_loss: 3.7213e-04
# Epoch 28/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 135ms/step - loss: 5.8094e-04 - val_loss: 3.7321e-04
# Epoch 29/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - loss: 5.9120e-04 - val_loss: 3.6562e-04
# Epoch 30/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 161ms/step - loss: 6.1279e-04 - val_loss: 4.5648e-04
# Epoch 31/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 6.7415e-04 - val_loss: 3.7417e-04
# Epoch 32/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - loss: 5.5684e-04 - val_loss: 4.5290e-04
# Epoch 33/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 160ms/step - loss: 6.8781e-04 - val_loss: 4.9286e-04
# Epoch 34/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 6.3791e-04 - val_loss: 3.5920e-04
# Epoch 35/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - loss: 5.9551e-04 - val_loss: 3.9103e-04
# Epoch 36/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 6.2016e-04 - val_loss: 3.4974e-04
# Epoch 37/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 5.6710e-04 - val_loss: 4.6286e-04
# Epoch 38/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - loss: 6.5269e-04 - val_loss: 4.9032e-04
# Epoch 39/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - loss: 5.8653e-04 - val_loss: 8.3758e-04
# Epoch 40/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 9.8854e-04 - val_loss: 5.2221e-04
# Epoch 41/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 160ms/step - loss: 6.8779e-04 - val_loss: 5.3170e-04
# Epoch 42/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 5.6541e-04 - val_loss: 6.3489e-04
# Epoch 43/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - loss: 7.6350e-04 - val_loss: 4.4791e-04
# Epoch 44/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 7s 167ms/step - loss: 7.7962e-04 - val_loss: 4.0758e-04
# Epoch 45/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - loss: 5.5101e-04 - val_loss: 3.4363e-04
# Epoch 46/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - loss: 6.5676e-04 - val_loss: 4.3751e-04
# Epoch 47/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 6.0048e-04 - val_loss: 3.3649e-04
# Epoch 48/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 5.5156e-04 - val_loss: 4.5017e-04
# Epoch 49/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 6.2709e-04 - val_loss: 3.4503e-04
# Epoch 50/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 6.2694e-04 - val_loss: 4.8060e-04
# Epoch 51/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 5.7655e-04 - val_loss: 3.7833e-04
# Epoch 52/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 5.9457e-04 - val_loss: 3.5566e-04
# Epoch 53/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 6.2963e-04 - val_loss: 3.9707e-04
# Epoch 54/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - loss: 7.4140e-04 - val_loss: 3.3329e-04
# Epoch 55/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - loss: 5.6058e-04 - val_loss: 3.3228e-04
# Epoch 56/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - loss: 6.0733e-04 - val_loss: 3.6757e-04
# Epoch 57/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - loss: 5.9396e-04 - val_loss: 3.4414e-04
# Epoch 58/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - loss: 5.7537e-04 - val_loss: 4.9935e-04
# Epoch 59/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - loss: 8.8491e-04 - val_loss: 4.5419e-04
# Epoch 60/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 5.5277e-04 - val_loss: 5.1666e-04
# Epoch 61/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 6.9003e-04 - val_loss: 5.5673e-04
# Epoch 62/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 6.5822e-04 - val_loss: 3.3120e-04
# Epoch 63/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 5.8203e-04 - val_loss: 5.2921e-04
# Epoch 64/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 5.7508e-04 - val_loss: 3.3217e-04
# Epoch 65/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - loss: 7.0134e-04 - val_loss: 5.2518e-04
# Epoch 66/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - loss: 6.9774e-04 - val_loss: 4.4691e-04
# Epoch 67/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 6.8330e-04 - val_loss: 3.5723e-04
# Epoch 68/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 5.4746e-04 - val_loss: 4.3925e-04
# Epoch 69/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 6.2317e-04 - val_loss: 4.0074e-04
# Epoch 70/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 7.0037e-04 - val_loss: 3.5120e-04
# Epoch 71/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 6.4894e-04 - val_loss: 4.1632e-04
# Epoch 72/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 5.9941e-04 - val_loss: 3.4415e-04

# %%
# Make Predictions and Inverse Scale
y_pred_scaled = model.predict(X_test)

# Inverse transform only the 'Close' column
temp_array = np.zeros((len(y_pred_scaled), len(features)))
temp_array[:, CLOSE_IDX] = y_pred_scaled.flatten()
y_pred = scaler.inverse_transform(temp_array)[:, CLOSE_IDX]

temp_array_true = np.zeros((len(y_test), len(features)))
temp_array_true[:, CLOSE_IDX] = y_test
y_true = scaler.inverse_transform(temp_array_true)[:, CLOSE_IDX]
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step

# %%
# Evaluate the Model
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
r2 = r2_score(y_true, y_pred)

print(f"Model evaluation for {ticker} on the test set:")
print(f"  MAE:  {mae:.2f}")
print(f"  RMSE: {rmse:.2f}")
print(f"  MAPE: {mape:.2f}%")
print(f"  R^2:  {r2:.4f}")
# Out:
# Model evaluation for TSLA on the test set:
#   MAE:  8.89
#   RMSE: 12.41
#   MAPE: 3.28%
#   R^2:  0.9755

# %%
# Plot Predictions and Loss Curve
plt.figure(figsize=(10, 4))
plt.plot(y_true, label="Actual Price")
plt.plot(y_pred, label="Predicted Price")
plt.title(f"Price Prediction for {ticker} using GRU")
plt.xlabel("Time Step")
plt.ylabel("Price")
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title(f"{ticker} - Loss Curve (GRU)")
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Save the trained model and the fitted scaler for later use
model.save(f"model/GRU_{ticker}_model.keras")
joblib.dump(scaler, f"scaler/GRU_{ticker}_scaler.pkl")
# Out:
# ['scaler/GRU_TSLA_scaler.pkl']
